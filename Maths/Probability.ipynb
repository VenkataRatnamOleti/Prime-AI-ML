# %%
from scipy.stats import binom

# %%
n = 5
k = 3
p = 0.5

# %%
prob = binom.pmf(k,n,p)   # -> Binomial Distribution

# %%
print(prob)
# Out:
# 0.31249999999999983

# %%
# Uniform Distribution

import numpy as np
import matplotlib.pyplot as plt

# %%
values = np.random.uniform(0,10,10_00_000)

plt.hist(values,bins=100, density=True,alpha=0.3)

plt.title("Continuous Uniform Distribution between 0 and 10")
plt.xlabel("x")
plt.ylabel("Probabiity Density")
plt.grid(True)

plt.show()

# %% [markdown]
# # Normal Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
mu = 70 # mean
sigma = 10 # std dev

# %%
x = np.linspace(30,110,1000)
y = norm.pdf(x,mu,sigma)

plt.plot(x,y,color="black",linewidth=2,label="Normal Distribution")

# %%
x1 = np.linspace(mu-sigma,mu-sigma,1000)
plt.fill_between(x1,norm.pdf(x1,mu,sigma),color="green",alpha=0.3,label="68% region (1σ)")

plt.show()

# %%
x = np.linspace(30, 110, 1000)

# Normal POF
y = norm.pdf(x, mu, sigma)

# Plot the bell curve
plt.plot(x, y, color='black', linewidth=2, label='Normal Distribution')

# Shade 68% region (u ± lo)
x1 = np.linspace(mu - sigma, mu + sigma, 1008)
plt.fill_between(x1, norm.pdf(x1, mu, sigma), color='green', alpha=0.3, label='684 region (1o)')
# venkataratnamoleti@gmail.com
# Shade 95% region (u ± 20)
x2 = np.linspace(mu - 2*sigma, mu + 2*sigma, 1000)
plt.fill_between(x2, norm.pdf(x2, mu, sigma), color='yellow', alpha=0.2, label='95% region (2o)')

# Shade 99.7% region (u ± 30)
x3 = np.linspace(mu - 3*sigma, mu + 3*sigma, 1000)
plt.fill_between(x3, norm.pdf(x3, mu, sigma), color='red', alpha=0.1, label='99.7% region (3o)')

# Labels and title
plt.title("Normal Distribution of Student Scores")
plt.xlabel("Score")
plt.ylabel("Probability Density")
plt.legend()
plt.show()
