# %%
# a picture is worth a thousand words

# ADVANTAGES
# 1. EDA
# 2. model evaluation
# 3. Stake holders communicate
# 4. Business/Research Decisions 

# How to plot
1. Problem
2. Less Noise
3. Story Telling
4. clarify - labels, abbreviation, units, scales, colors
