# %%
# Web Scraping

# Involves programmatically extracting data from websites

# 1. Terms & Conditions check in websites
# 2. APIs  >>  scraping
# 3. rate limits, exhaustive calls can ban ip's

# requests & BeautifulSoup Parses & extracts from --static HTML--
# Selenium -> alternative to (requests & beautifulSoup) in case of --Dynamic websites--

# %%
import requests

URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
# print(res.status_code)
# print(res.text)
# if res.status_code == 200:
    # print(res.text)
    # print(res.content)
    # print(res.headers)

with open("scraped_data/data1.html","w",encoding="utf-8") as f:
    f.write(res.text)

# %%
# Headers
# "User-Agent": "Mozilla/5.0"

# try - exception handling

# delay

# %%
# webscraping using beautifulsoup

# Parse
# lxml -> fast parsing

# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in a:\anaconda\lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in a:\anaconda\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in a:\anaconda\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
from bs4 import BeautifulSoup

with open("scraped_data/data1.html","r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content,"lxml")

# %%
soup

# Methods
# 1. find()
# 2. find_all()
# 3. find_parent()
# 4. find_next()
# 5. find_previous()
