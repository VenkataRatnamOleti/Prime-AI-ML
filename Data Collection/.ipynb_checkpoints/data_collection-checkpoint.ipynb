# %% [markdown]
# # Part - 1

# %%
# Data Collection
# data science steps
# 1. Define the Problem
# 2. Data Collection
# 3. EDA                                 --\
# 4. Data Cleaning & Pre-processing      ---> Pandas (Previously learned)
# 5. Feature Engineering                 --/
# 6. Modeling
# 7. Evaluation
# 8. Deployment

# data collection depends on problem
# Kaggle, Db/Sql, Devices(health wearables)

# Sources -> Primary
#         -> Secondary 

# Garbage In, Garbage Out

# %%
# Sources (Primary,Secondary,System)
# secondary
# -> Databases : SQL(MySQL, PostgreSQL etc,), NoSQL databases (MongoDB etc.)
# -> Public Datasets : Kaggle, UCI(university of california) ML Repo etc.
# -> APIs : Twitter API, Stock API, Weather API etc.
# -> Web Scraping - HTML pages, blogs/articles, social media pages etc.
# -> Sensors & Devices : IoT devices, health wearables etc.
# -> Surveys & Forms : customer satisfaction, feedback etc.
# -> System Generated : logs, video feeds, synthetic data(using GAN's) etc.

# Databases Data -> Reliable, Relevant, Cost Effective
